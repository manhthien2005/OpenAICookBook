# %%
# !pip install "distilabel[hf-inference-endpoints]"
# Out:
# Requirement already satisfied: distilabel[hf-inference-endpoints] in /usr/local/lib/python3.11/dist-packages (1.5.3)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (3.3.2)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (3.1.6)
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (0.70.16)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (3.4.2)
# Requirement already satisfied: orjson>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (3.10.15)
# Requirement already satisfied: portalocker>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (3.1.1)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (2.10.6)
# Requirement already satisfied: rich>=13.5.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (13.9.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (1.13.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (75.1.0)
# Requirement already satisfied: tblib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (3.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (0.15.2)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (0.2.6)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-inference-endpoints]) (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (3.5.0)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (3.11.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-inference-endpoints]) (6.0.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-inference-endpoints]) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-inference-endpoints]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-inference-endpoints]) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-inference-endpoints]) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->distilabel[hf-inference-endpoints]) (0.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.22.0->distilabel[hf-inference-endpoints]) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.2->distilabel[hf-inference-endpoints]) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->distilabel[hf-inference-endpoints]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->distilabel[hf-inference-endpoints]) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.0->distilabel[hf-inference-endpoints]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.0->distilabel[hf-inference-endpoints]) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->distilabel[hf-inference-endpoints]) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->distilabel[hf-inference-endpoints]) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (1.18.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.0->distilabel[hf-inference-endpoints]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.2->distilabel[hf-inference-endpoints]) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->distilabel[hf-inference-endpoints]) (1.17.0)

# %%
# !pip install "transformers~=4.0" "torch~=2.0"
# Out:
# Requirement already satisfied: transformers~=4.0 in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: torch~=2.0 in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch~=2.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch~=2.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers~=4.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers~=4.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers~=4.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers~=4.0) (2025.1.31)

# %% [markdown]
# Let's make the required imports:

# %%
from distilabel.llms import InferenceEndpointsLLM
from distilabel.pipeline import Pipeline
from distilabel.steps import (
    LoadDataFromHub,
    GroupColumns,
    FormatTextGenerationDPO,
    PreferenceToArgilla,
)
from distilabel.steps.tasks import TextGeneration, UltraFeedback

# %%
import os
from huggingface_hub import login

login(token=os.getenv("HF_TOKEN"), add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
os.environ["HF_TOKEN"] = "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"

# %%
# !pip install "distilabel[argilla, hf-inference-endpoints]"
# Out:
# Requirement already satisfied: distilabel[argilla,hf-inference-endpoints] in /usr/local/lib/python3.11/dist-packages (1.5.3)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (3.3.2)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (3.1.6)
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (0.70.16)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (3.4.2)
# Requirement already satisfied: orjson>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (3.10.15)
# Requirement already satisfied: portalocker>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (3.1.1)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (2.10.6)
# Requirement already satisfied: rich>=13.5.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (13.9.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (1.13.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (75.1.0)
# Requirement already satisfied: tblib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (3.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (0.15.2)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (0.2.6)
# Requirement already satisfied: argilla>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (2.8.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (7.34.0)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[argilla,hf-inference-endpoints]) (0.28.1)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.11/dist-packages (from argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (4.67.1)
# Requirement already satisfied: pillow>=9.5.0 in /usr/local/lib/python3.11/dist-packages (from argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (11.1.0)
# Requirement already satisfied: standardwebhooks>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (1.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (3.5.0)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (3.11.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (6.0.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[argilla,hf-inference-endpoints]) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[argilla,hf-inference-endpoints]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[argilla,hf-inference-endpoints]) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[argilla,hf-inference-endpoints]) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->distilabel[argilla,hf-inference-endpoints]) (0.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.22.0->distilabel[argilla,hf-inference-endpoints]) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.2->distilabel[argilla,hf-inference-endpoints]) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->distilabel[argilla,hf-inference-endpoints]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->distilabel[argilla,hf-inference-endpoints]) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.0->distilabel[argilla,hf-inference-endpoints]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.0->distilabel[argilla,hf-inference-endpoints]) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->distilabel[argilla,hf-inference-endpoints]) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->distilabel[argilla,hf-inference-endpoints]) (1.5.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (3.0.50)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->distilabel[argilla,hf-inference-endpoints]) (4.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (1.18.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->distilabel[argilla,hf-inference-endpoints]) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.0->distilabel[argilla,hf-inference-endpoints]) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->distilabel[argilla,hf-inference-endpoints]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->distilabel[argilla,hf-inference-endpoints]) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (2.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from standardwebhooks>=1.0.0->argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (2.8.2)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from standardwebhooks>=1.0.0->argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (1.2.18)
# Requirement already satisfied: types-python-dateutil in /usr/local/lib/python3.11/dist-packages (from standardwebhooks>=1.0.0->argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (2.9.0.20241206)
# Requirement already satisfied: types-Deprecated in /usr/local/lib/python3.11/dist-packages (from standardwebhooks>=1.0.0->argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (1.2.15.20250304)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.2->distilabel[argilla,hf-inference-endpoints]) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[argilla,hf-inference-endpoints]) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->standardwebhooks>=1.0.0->argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->standardwebhooks>=1.0.0->argilla>=2.0.0->distilabel[argilla,hf-inference-endpoints]) (1.17.2)

# %%
load_dataset = LoadDataFromHub(
        repo_id= "argilla/10Kprompts-mini",
        num_examples=1,
        pipeline=Pipeline(name="showcase-pipeline"),
    )
load_dataset.load()
next(load_dataset.process())
# Out:
# ([{'instruction': 'How can I create an efficient and robust workflow that utilizes advanced automation techniques to extract targeted data, including customer information, from diverse PDF documents and effortlessly integrate it into a designated Google Sheet? Furthermore, I am interested in establishing a comprehensive and seamless system that promptly activates an SMS notification on my mobile device whenever a new PDF document is uploaded to the Google Sheet, ensuring real-time updates and enhanced accessibility.',
#    'topic': 'Software Development'}],
#  True)

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model="meta-llama/Meta-Llama-3-8B-Instruct", token="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")
response = client.text_generation("Which are the top cities in Spain?", max_new_tokens=100)
print(response)
# Out:
#  Here are the top 10 cities in Spain, based on population, economy, culture, and tourism:
# 1. Madrid: The capital city of Spain, Madrid is the largest city in the country and is known for its rich cultural heritage, vibrant nightlife, and world-class museums like the Prado and Reina Sofia.
# 2. Barcelona: The second-largest city in Spain, Barcelona is a popular tourist destination known for its stunning architecture, beaches, and cultural attractions like the Sagrada Familia and Park

# %%
group_responses = GroupColumns(
    columns=["generation", "model_name"],
    output_columns=["generations", "model_names"],
    pipeline=Pipeline(name="showcase-pipeline"),
)
next(
    group_responses.process(
        [
            {
                "generation": "Madrid",
                "model_name": "meta-llama/Meta-Llama-3-8B-Instruct",
            },
        ],
        [
            {
                "generation": "Barcelona",
                "model_name": "mistralai/Mixtral-8x7B-Instruct-v0.1",
            }
        ],
    )
)
# Out:
# [{'generations': ['Madrid', 'Barcelona'],
#   'model_names': ['meta-llama/Meta-Llama-3-8B-Instruct',
#    'mistralai/Mixtral-8x7B-Instruct-v0.1']}]

# %%
response = client.text_generation("What's the capital of Spain?", max_new_tokens=50)
print(response)
# Out:
#  Madrid, of course! But did you know that the city has a rich history dating back to the 9th century? From the Royal Palace to the Prado Museum, there's so much to see and do in this vibrant city. So,

# %%
format_dpo = FormatTextGenerationDPO(pipeline=Pipeline(name="showcase-pipeline"))
format_dpo.load()
next(
    format_dpo.process(
        [
            {
                "instruction": "What's the capital of Spain?",
                "generations": ["Madrid", "Barcelona"],
                "generation_models": [
                    "Meta-Llama-3-8B-Instruct",
                    "Mixtral-8x7B-Instruct-v0.1",
                ],
                "ratings": [5, 1],
            }
        ]
    )
)
# Out:
# [{'instruction': "What's the capital of Spain?",
#   'generations': ['Madrid', 'Barcelona'],
#   'generation_models': ['Meta-Llama-3-8B-Instruct',
#    'Mixtral-8x7B-Instruct-v0.1'],
#   'ratings': [5, 1],
#   'prompt': "What's the capital of Spain?",
#   'prompt_id': '26174c953df26b3049484e4721102dca6b25d2de9e3aa22aa84f25ed1c798512',
#   'chosen': [{'role': 'user', 'content': "What's the capital of Spain?"},
#    {'role': 'assistant', 'content': 'Madrid'}],
#   'chosen_model': 'Meta-Llama-3-8B-Instruct',
#   'chosen_rating': 5,
#   'rejected': [{'role': 'user', 'content': "What's the capital of Spain?"},
#    {'role': 'assistant', 'content': 'Barcelona'}],
#   'rejected_model': 'Mixtral-8x7B-Instruct-v0.1',
#   'rejected_rating': 1}]

# %%
to_argilla = PreferenceToArgilla(
    dataset_name="preference-dataset",
    dataset_workspace="argilla",
    api_url="https://[your-owner-name]-[your-space-name].hf.space",
    api_key="[your-api-key]",
    num_generations=2
)
# Out:
# [03/11/25 13:04:06] WARNING  ['distilabel.step.None'] Step 'None' hasn't received a pipeline, and it    ]8;id=851694;file:///usr/local/lib/python3.11/dist-packages/distilabel/steps/base.py\base.py]8;;\:]8;id=389471;file:///usr/local/lib/python3.11/dist-packages/distilabel/steps/base.py#222\222]8;;\
#                              hasn't been created within a `Pipeline` context. Please, use `with
#                              Pipeline() as pipeline:` and create the step within the context.
